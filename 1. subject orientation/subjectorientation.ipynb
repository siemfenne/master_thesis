# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HadCRUT5_summary_series.csv')
df.head()
# Out:
#       Time  Anomaly (deg C)  Lower confidence limit (2.5%)  \
# 0  1850-01        -0.674564                      -0.981772
# 1  1850-02        -0.333416                      -0.700901
# 2  1850-03        -0.591323                      -0.933919
# 3  1850-04        -0.588721                      -0.898259
# 4  1850-05        -0.508185                      -0.761214
#
#    Upper confidence limit (97.5%)
# 0                       -0.367357
# 1                        0.034069
# 2                       -0.248726
# 3                       -0.279183
# 4                       -0.255157

# %%
df['Time'] = pd.to_datetime(df['Time'])
df
# Out:
#            Time  Anomaly (deg C)  Lower confidence limit (2.5%)  \
# 0    1850-01-01        -0.674564                      -0.981772
# 1    1850-02-01        -0.333416                      -0.700901
# 2    1850-03-01        -0.591323                      -0.933919
# 3    1850-04-01        -0.588721                      -0.898259
# 4    1850-05-01        -0.508185                      -0.761214
# ...         ...              ...                            ...
# 2080 2023-05-01         0.871212                       0.817516
# 2081 2023-06-01         1.051591                       0.995718
# 2082 2023-07-01         1.149915                       1.089173
# 2083 2023-08-01         1.199122                       1.130246
# 2084 2023-09-01         1.347491                       1.289244
#
#       Upper confidence limit (97.5%)
# 0                          -0.367357
# 1                           0.034069
# 2                          -0.248726
# 3                          -0.279183
# ...

# %%
plt.plot(df['Time'], df['Anomaly (deg C)'], linewidth=0.5)
plt.xlabel('Time (years)')
plt.ylabel('Anomaly (deg C) relative to 1961-1990')
plt.savefig('tempseries.png', bbox_inches='tight', dpi=300)
plt.show()
